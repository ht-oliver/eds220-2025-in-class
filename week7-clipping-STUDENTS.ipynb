# %% [markdown]
# # 12 Clipping
#
# In this lesson we will learn how to to clip different geometries.
#
# ## About the data
#
# We will use three datasets in this lesson.
#
# The first dataset is a [TIGER shapefile of the US states from the United States Census Bureau](https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.2022.html#list-tab-790442341). Follow these steps to download shapefile with the United States' states:
#
# You can check the [metadata for all the TIGER shapefiles here](https://www.census.gov/programs-surveys/geography/technical-documentation/complete-technical-documentation/tiger-geo-line.html).
#
# The second dataset we'll use is [Natural Earth's simple medium scale populated places dataset](https://www.naturalearthdata.com/downloads/50m-cultural-vectors/). We can obtain this dataset by downloading the shapefile (choose the one that says "simple (less columns)").
#
# The third dataset we'll use is [Natural Earth's road dataset](https://www.naturalearthdata.com/downloads/10m-cultural-vectors/roads/).
# We can obtain this dataset by downloading the shapefile
#
# We will combine these datasets to create the following map of infrastructure in Alaska:
#
# ## Import data
#
# Let's start by loading our libraries and then importing the datasets we will use.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

from shapely.geometry import box  # To create polygon bounding box


pd.set_option("display.max.columns", None)

# -------------------------------------------------------
# Import and simplify states polygons
states = gpd.read_file(os.path.join('data', 
                                    'tl_2022_us_state', 
                                    'tl_2022_us_state.shp'))

# Import Natural Earth populated places points
places = gpd.read_file(os.path.join('data',
                                    'ne_50m_populated_places_simple',
                                    'ne_50m_populated_places_simple.shp')
                                    )

# Import ferry routes lines
roads = gpd.read_file(os.path.join('data',
                                   'ne_10m_roads',
                                   'ne_10m_roads.shp')
                                   )

# %% [markdown]
# ## Check-in
# Use a for loop to iterate over the three geo-dataframes we imported and change their column names to lower caps.

# %%
df_list = [states, places, roads]

for df in df_list:
    df.columns = [col.lower() for col in df.columns]

# %%
states.head()
# Out:
#   region division statefp   statens geoid stusps           name lsad  mtfcc  \
# 0      3        5      54  01779805    54     WV  West Virginia   00  G4000
# 1      3        5      12  00294478    12     FL        Florida   00  G4000
# 2      2        3      17  01779784    17     IL       Illinois   00  G4000
# 3      2        4      27  00662849    27     MN      Minnesota   00  G4000
# 4      3        5      24  01714934    24     MD       Maryland   00  G4000
#
#   funcstat         aland       awater     intptlat      intptlon  \
# 0        A   62266456923    489045863  +38.6472854  -080.6183274
# 1        A  138962819934  45971472526  +28.3989775  -082.5143005
# 2        A  143778515726   6216539665  +40.1028754  -089.1526108
# 3        A  206244837557  18937184315  +46.3159573  -094.1996043
# 4        A   25151771744   6979295311  +38.9466584  -076.6744939
#
#                                             geometry
# 0  POLYGON ((-77.75438 39.33346, -77.75422 39.333...
# 1  MULTIPOLYGON (((-83.10874 24.62949, -83.10711 ...
# 2  POLYGON ((-87.89243 38.28285, -87.89334 38.282...
# 3  POLYGON ((-95.31989 48.99892, -95.31747 48.998...
# 4  POLYGON ((-75.75600 39.24607, -75.75579 39.243...

# %% [markdown]
# ## Prepare Alaska Multipolygon
#
# Examine data.

# %%
print(f"CRS: {states.crs}")
# Out:
# CRS: EPSG:4269

# %%
states.plot()
# Out:
# <Axes: >

# %%
alaska = states[states['name'] == 'Alaska']
alaska.plot()
# Out:
# <Axes: >

# %%
# Reproject to CRS optimized for Alaska
alaska = alaska.to_crs('epsg:3338')

# Inspect the new CRS
print('Is this CRS projected? ', alaska.crs.is_projected)
alaska.crs
# Out:
# Is this CRS projected?  True
# <Projected CRS: EPSG:3338>
# Name: NAD83 / Alaska Albers
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - Alaska.
# - bounds: (172.42, 51.3, -129.99, 71.4)
# Coordinate Operation:
# - name: Alaska Albers (meter)
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
alaska.plot()
# Out:
# <Axes: >

# %%
print('CRS: ', places.crs)

places.head()
# Out:
# CRS:  EPSG:4326
#    scalerank  natscale  labelrank              featurecla         name  \
# 0         10         1          5  Admin-1 region capital        Bombo
# 1         10         1          5  Admin-1 region capital  Fort Portal
# 2         10         1          3  Admin-1 region capital      Potenza
# 3         10         1          3  Admin-1 region capital   Campobasso
# 4         10         1          3  Admin-1 region capital        Aosta
#
#   namepar namealt    nameascii  adm0cap  capalt capin  worldcity  megacity  \
# 0    None    None        Bombo        0       0  None          0         0
# 1    None    None  Fort Portal        0       0  None          0         0
# 2    None    None      Potenza        0       0  None          0         0
# 3    None    None   Campobasso        0       0  None          0         0
# 4    None    None        Aosta        0       0  None          0         0
#
#   sov0name sov_a3 adm0name adm0_a3       adm1name iso_a2  note   latitude  \
# 0   Uganda    UGA   Uganda     UGA     Bamunanika     UG  None   0.583299
# 1   Uganda    UGA   Uganda     UGA       Kabarole     UG  None   0.671004
# 2    Italy    ITA    Italy     ITA     Basilicata     IT  None  40.642002
# 3    Italy    ITA    Italy     ITA         Molise     IT  None  41.562999
# 4    Italy    ITA    Italy     ITA  Valle d'Aosta     IT  None  45.737001
#
#    longitude  pop_max  pop_min  pop_other  rank_max  rank_min meganame  \
# 0  32.533300    75000    21000        0.0         8         7     None
# 1  30.275002    42670    42670        0.0         7         7     None
# 2  15.798997    69060    69060        0.0         8         8     None
# 3  14.655997    50762    50762        0.0         8         8     None
# 4   7.315003    34062    34062        0.0         7         7     None
#
#   ls_name  min_zoom       ne_id                   geometry
# 0    None       7.0  1159113923   POINT (32.53330 0.58330)
# 1    None       7.0  1159113959   POINT (30.27500 0.67100)
# 2    None       7.0  1159117259  POINT (15.79900 40.64200)
# 3    None       7.0  1159117283  POINT (14.65600 41.56300)
# 4    None       7.0  1159117361   POINT (7.31500 45.73700)

# %%
places.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()

alaska.plot(ax=ax)
places.plot(ax=ax, color = 'red')

plt.show()

# %% [markdown]
# **Data in weird places? Check that the CRSs match.**
# To plot, analyze, or integrate different geospatial datasets they **must have the same CRS**

# %% [markdown]
# ## Check-in
# Reproject the `places` geo-dataframe into `alaska`'s CRS and verify the CRSs match using `assert`

# %%
# Change CRS
places = places.to_crs(alaska.crs)

assert alaska.crs == places.crs

# %%
fig, ax = plt.subplots()

alaska.plot(ax=ax)
places.plot(ax=ax, color = 'red')

plt.show()

# %% [markdown]
# ## Clipping
#
# **Clipping** means using a polygon(s) to only select data within them.
#
# Syntax:
# ```
# updated_geodf = geopandas.clip(geodf, mask)
# ```
#
# where:
# - `updated_geodf` = intersection of geometries in `geodf` with `mask`
# - `mask` = `gpd.GeoDataFrame` with the polygons you want to use for clipping.
#
# Make sure the CRSs for `mask` and `geodf` match.

# %%
# Clip populated places to Alaska multipolygon
ak_places = gpd.clip(places, alaska)

# %%
fig, ax = plt.subplots()

alaska.plot(ax=ax, color = 'lightblue')
ak_places.plot(ax=ax, color = 'blue')

plt.show()

# %% [markdown]
# ## Prepare roads
# Examine the roads dataset

# %%
print('CRS: ', roads.crs)
roads.head()
# Out:
# CRS:  EPSG:4326
#    scalerank featurecla               type sov_a3  note  \
# 0          8       Road  Secondary Highway    CAN  None
# 1          7       Road  Secondary Highway    USA  None
# 2          7       Road  Secondary Highway    USA  None
# 3          8       Road  Secondary Highway    USA  None
# 4          6       Road      Major Highway    USA  None
#
#                                               edited  name namealt namealtt  \
# 0  Version 1.5: Changed alignment, a few adds in ...  None    None     None
# 1  Version 1.5: Changed alignment, a few adds in ...    83    None     None
# 2  Version 1.5: Changed alignment, a few adds in ...   840    None     None
# 3  Version 1.5: Changed alignment, a few adds in ...   151    None     None
# 4  Version 1.5: Changed alignment, a few adds in ...   GSP    None     None
#
#   routeraw  question  length_km  toll          ne_part label label2 local  \
# 0     None         0          3     0  ne_1d4_original  None   None  None
# 1     None         0        164     0  ne_1d4_original  None   None  None
# 2     None         0         98     0  ne_1d4_original  None   None  None
# 3     None         0         17     0  ne_1d4_original  None   None  None
# 4     None         0         33     1  ne_1d4_original  None   None  None
#
#   localtype localalt  labelrank  ignore  add  rwdb_rd_id  orig_fid prefix  \
# 0      None     None          0       0    0           0         0   None
# 1      None     None          0       0    0           0         0   None
# 2      None     None          0       0    0           0         0   None
# 3      None     None          0       0    0           0         0   None
# 4      None     None          0       0    0           0         0   None
#
#    uident      continent  expressway    level  min_zoom  min_label  \
# 0  314705  North America           0     None       7.1        9.6
# 1  108105  North America           0  Federal       7.0        8.6
# 2       0  North America           0      U/C       7.0        9.5
# 3       0  North America           0  Federal       7.1        9.6
# 4  311305  North America           1    State       6.0        8.5
#
#                                             geometry
# 0  LINESTRING (-133.32533 62.21571, -133.31664 62...
# 1  LINESTRING (-100.50543 42.80753, -100.53495 42...
# 2  LINESTRING (-87.27432 36.02439, -87.22916 35.9...
# 3  LINESTRING (-87.72757 44.15165, -87.57301 44.1...
# 4  MULTILINESTRING ((-74.75920 39.14301, -74.6735...

# %% [markdown]
# Before jumping into reprojecting and clipping, we will subset the data to select only US roads
#
# It's good practice to reduce geospatial data as much as possible before applying geospatial transformations

# %%
usa_roads = roads[roads['sov_a3'] == 'USA']

# %%
# Clip usa_roads to alaska geometry
ak_roads = gpd.clip(usa_roads.to_crs(alaska.crs), alaska)

# %%
#Plot 
fig, ax = plt.subplots()
alaska.plot(ax=ax, color = 'lightblue')
ak_roads.plot(ax = ax, color = 'orange')
plt.show()

# %% [markdown]
# Parts of our roads were left out because they went between islands (ferry paths). We want these, so we need to find another way to clip
#
# ## Clipping with a Bounding Box
#
# We will clip the `usa_roads` geo-df with the **bounding box** of `alaska` instead of the polygons.
#
# We will create the bounding box with `box()` function from `shapely`
#
# We construct a box by passing 4 numbers into `box()`
# `box(minx, miny, maxx, maxy)`

# %%
# Get rectangular bounds of a spatial object
alaska.total_bounds
# Out:
# array([-2175729.73162241,   404545.10791528,  1493082.30904445,
#         2383808.43520815])

# %%
# We could copy-paste what total_bounds returned
# We use the `*` unpacks and passed each number from total_bounds
bbox = box(*alaska.total_bounds)
print(type(bbox))
bbox
# Out:
# <class 'shapely.geometry.polygon.Polygon'>
# <POLYGON ((1493082.309 404545.108, 1493082.309 2383808.435, -2175729.732 238...>

# %% [markdown]
# `*` = unpacking operator
#
# Think about is as "unpacking" the lements in `alaska.total_bounds` and assignging them one-by-one to the parameters of the `box()` function
#
# This works with most iterables

# %%
# Array
print(['a', 'b', 'c'])
# Unpacked
print(*['a', 'b', 'c'])
# Out:
# ['a', 'b', 'c']
# a b c

# %%
# Create a geo-dataframe from the alaska bbox
ak_bbox = gpd.GeoDataFrame(geometry = [bbox], # Assign geometry column
                           crs = alaska.crs)  # Assign CRS
ak_bbox.plot()
# Out:
# <Axes: >

# %% [markdown]
# Clip the roads using Alaska's bounding box

# %%
ak_complete_roads = gpd.clip(usa_roads.to_crs(ak_bbox.crs), ak_bbox)

# %%
# Comapre both clipping methods

fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (10, 10))

ak_roads.plot(ax=ax1)
ax1.set_title('Roads clipped with AK multipolygon')

ak_complete_roads.plot(ax=ax2)
ax2.set_title('Roads clipped with AK bbox')

plt.show()

# %% [markdown]
# ## Create Map

# %%
fig, ax = plt.subplots(figsize=(11,5))
ax.axis('off')

alaska.plot(ax = ax, color = 'whitesmoke', edgecolor = '0.7')

ak_complete_roads.plot(ax=ax,
                       zorder=1, # Specify layer plotting order
                       column = 'type',
                       legend=True
                       )

ak_places.plot(ax=ax,
               zorder=2,
               color='hotpink',
               marker='s' # Square marker
               )

ax.set_title('Raod Networks and major Cities in Alaska', fontsize=14, fontweight = 'bold')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(11,5))
ax.axis('off')

alaska.plot(ax = ax, color = 'whitesmoke', edgecolor = '0.7')

ak_complete_roads.plot(ax=ax,
                       zorder=1, # Specify layer plotting order
                       column = 'type',
                       legend=True,
                       legend_kwds={'title': "Road Types", 
                                    'loc': 'upper left',
                                    'bbox_to_anchor':(0,0.9),
                                    'fontsize':'small'}
                       )

ak_places.plot(ax=ax,
               zorder=2,
               color='hotpink',
               marker='s' # Square marker
               )

# Add city names as text annotations
for x, y, name in zip(ak_places.geometry.x, ak_places.geometry.y, ak_places['name']):
    ax.text(x-30000, y+20000, name, fontsize=8, ha='right')

ax.set_title('Raod Networks and major Cities in Alaska', fontsize=14, fontweight = 'bold')

plt.show()

# %% [markdown]
# ```
# # Add city names as text annotations
# for x, y, name in zip(ak_places.geometry.x, ak_places.geometry.y, ak_places['name']):
#     ax.text(x-30000, y+20000, name, fontsize=8, ha='right')
# ```
#
# This chunk of code goes through each name, and adds text relative to the point for that name.
# Units of text adjustment are same as CRS units.
#
#
# What if you want to adjust one name position?

# %%
fig, ax = plt.subplots(figsize=(11,5))
ax.axis('off')

alaska.plot(ax = ax, color = 'whitesmoke', edgecolor = '0.7')

ak_complete_roads.plot(ax=ax,
                       zorder=1, # Specify layer plotting order
                       column = 'type',
                       legend=True,
                       legend_kwds={'title': "Road Types", 
                                    'loc': 'upper left',
                                    'bbox_to_anchor':(0,0.9),
                                    'fontsize':'small'}
                       )

ak_places.plot(ax=ax,
               zorder=2,
               color='hotpink',
               marker='s' # Square marker
               )

# Add city names as text annotations

for x, y, name in zip(ak_places.geometry.x, ak_places.geometry.y, ak_places['name']):
    if name == "Valdez":
        ax.text(x+220000, y+45000, name, fontsize=8, ha='right')
    else:
        ax.text(x-30000, y+20000, name, fontsize=8, ha='right')


ax.set_title('Road Networks and major Cities in Alaska', fontsize=14, fontweight = 'bold')

plt.show()
